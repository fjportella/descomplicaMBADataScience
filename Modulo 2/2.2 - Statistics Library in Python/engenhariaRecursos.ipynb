# %%
import pandas as pd

# %%
df = pd.read_csv('/workspaces/descomplicaMBADataScience/Bovespa.csv')
df
# Out:
#             Date Ticker   Open   High    Low  Close   Volume Adj Close
# 0      27/9/2016  VALE3  17,35  17,63   17,1   17,6  3173900      17,6
# 1      26/9/2016  VALE3  17,39  17,68  17,38  17,44  2331200     17,44
# 2      23/9/2016  VALE3  17,47  17,84  17,31  17,65  4769800     17,65
# 3      22/9/2016  VALE3  17,86  17,96  17,32  17,55  5386000     17,55
# 4      21/9/2016  VALE3  17,21  17,65   17,1  17,65  7617300     17,65
# ...          ...    ...    ...    ...    ...    ...      ...       ...
# 14972  5/10/2015  ELPL4  10,68  10,82  10,44  10,64   588200   10,3369
# 14973  2/10/2015  ELPL4  10,51  10,81  10,26  10,52   915800   10,2203
# 14974  1/10/2015  ELPL4  10,94   11,2  10,52  10,57  1858100   10,2689
# 14975  30/9/2015  ELPL4  10,78  11,05  10,66  10,95   401000   10,6381
# 14976  29/9/2015  ELPL4  10,83  11,05  10,42  10,77   616000   10,4632
#
# [14977 rows x 8 columns]

# %%
df_vale = df[df['Ticker'] == 'VALE3']
df_vale
# Out:
#           Date Ticker   Open   High    Low  Close   Volume Adj Close
# 0    27/9/2016  VALE3  17,35  17,63   17,1   17,6  3173900      17,6
# 1    26/9/2016  VALE3  17,39  17,68  17,38  17,44  2331200     17,44
# 2    23/9/2016  VALE3  17,47  17,84  17,31  17,65  4769800     17,65
# 3    22/9/2016  VALE3  17,86  17,96  17,32  17,55  5386000     17,55
# 4    21/9/2016  VALE3  17,21  17,65   17,1  17,65  7617300     17,65
# ..         ...    ...    ...    ...    ...    ...      ...       ...
# 257  2/10/2015  VALE3  17,08  17,93  16,87  17,82  7116900  17,46904
# 258  1/10/2015  VALE3  16,81  17,51  16,71  17,22  6028900  16,88085
# 259  30/9/2015  VALE3  16,96  17,05  16,33  16,58  6672100  16,25346
# 260  29/9/2015  VALE3   16,8  17,18  16,43  16,48  7694600  16,15543
# 261  28/9/2015  VALE3   17,7   17,7  16,57  16,59  7584400  16,26326
#
# [262 rows x 8 columns]

# %%
df_vale.dtypes
# Out:
# Date         object
# Ticker       object
# Open         object
# High         object
# Low          object
# Close        object
# Volume        int64
# Adj Close    object
# dtype: object

# %%
#converte campo data que era objeto para tipo data
df_vale['Date'] = pd.to_datetime(df_vale['Date'], format='%d/%m/%Y')
# Out:
# /tmp/ipykernel_1732/3760650247.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vale['Date'] = pd.to_datetime(df_vale['Date'], format='%d/%m/%Y')

# %%
#converte campo open que era objeto para tipo float
# Passo 1: Substituir vírgula por ponto no campo 'Open'
df_vale['Open'] = df_vale['Open'].str.replace(',', '.')

# Passo 2: Converter o campo 'Open' para float
df_vale['Open'] = df_vale['Open'].astype(float)
# Out:
# /tmp/ipykernel_1732/1160859514.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vale['Open'] = df_vale['Open'].str.replace(',', '.')
# /tmp/ipykernel_1732/1160859514.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vale['Open'] = df_vale['Open'].astype(float)

# %%
df_vale['High'] = df_vale['High'].str.replace(',', '.')
df_vale['High'] = df_vale['High'].astype(float)

df_vale['Low'] = df_vale['Low'].str.replace(',', '.')
df_vale['Low'] = df_vale['Low'].astype(float)

df_vale['Close'] = df_vale['Close'].str.replace(',', '.')
df_vale['Close'] = df_vale['Close'].astype(float)
# Out:
# /tmp/ipykernel_1732/3243521251.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vale['High'] = df_vale['High'].str.replace(',', '.')
# /tmp/ipykernel_1732/3243521251.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vale['High'] = df_vale['High'].astype(float)
# /tmp/ipykernel_1732/3243521251.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_vale.dtypes
# Out:
# Date         datetime64[ns]
# Ticker               object
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close            object
# dtype: object

# %%
#criando campo média movel para 5 dias e 21 dias
df_vale['mm5d'] = df_vale['Close'].rolling(5).mean()
df_vale['mm21d'] = df_vale['Close'].rolling(21).mean()
# Out:
# /tmp/ipykernel_1732/2807054449.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vale['mm5d'] = df_vale['Close'].rolling(5).mean()
# /tmp/ipykernel_1732/2807054449.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vale['mm21d'] = df_vale['Close'].rolling(21).mean()

# %%
df_vale
# Out:
#           Date Ticker   Open   High    Low  Close   Volume Adj Close    mm5d  \
# 0   2016-09-27  VALE3  17.35  17.63  17.10  17.60  3173900      17,6     NaN
# 1   2016-09-26  VALE3  17.39  17.68  17.38  17.44  2331200     17,44     NaN
# 2   2016-09-23  VALE3  17.47  17.84  17.31  17.65  4769800     17,65     NaN
# 3   2016-09-22  VALE3  17.86  17.96  17.32  17.55  5386000     17,55     NaN
# 4   2016-09-21  VALE3  17.21  17.65  17.10  17.65  7617300     17,65  17.578
# ..         ...    ...    ...    ...    ...    ...      ...       ...     ...
# 257 2015-10-02  VALE3  17.08  17.93  16.87  17.82  7116900  17,46904  18.896
# 258 2015-10-01  VALE3  16.81  17.51  16.71  17.22  6028900  16,88085  18.328
# 259 2015-09-30  VALE3  16.96  17.05  16.33  16.58  6672100  16,25346  17.614
# 260 2015-09-29  VALE3  16.80  17.18  16.43  16.48  7694600  16,15543  17.248
# 261 2015-09-28  VALE3  17.70  17.70  16.57  16.59  7584400  16,26326  16.938
#
#          mm21d
# 0          NaN
# ...

# %%
#criando outro dataframe excluindo algumas colunas que não interessam. passando axis=1 para indicar que será por coluna
featuares = df_vale.drop(['Date', 'Ticker'], axis=1)
featuares
# Out:
#       Open   High    Low  Close   Volume Adj Close    mm5d      mm21d
# 0    17.35  17.63  17.10  17.60  3173900      17,6     NaN        NaN
# 1    17.39  17.68  17.38  17.44  2331200     17,44     NaN        NaN
# 2    17.47  17.84  17.31  17.65  4769800     17,65     NaN        NaN
# 3    17.86  17.96  17.32  17.55  5386000     17,55     NaN        NaN
# 4    17.21  17.65  17.10  17.65  7617300     17,65  17.578        NaN
# ..     ...    ...    ...    ...      ...       ...     ...        ...
# 257  17.08  17.93  16.87  17.82  7116900  17,46904  18.896  18.380952
# 258  16.81  17.51  16.71  17.22  6028900  16,88085  18.328  18.388571
# 259  16.96  17.05  16.33  16.58  6672100  16,25346  17.614  18.409524
# 260  16.80  17.18  16.43  16.48  7694600  16,15543  17.248  18.405238
# 261  17.70  17.70  16.57  16.59  7584400  16,26326  16.938  18.384286
#
# [262 rows x 8 columns]

# %%
#transformando dados categóricos (ex. string) para campos numéricos. 
#podemos fazer um encode usando a função dummies no pandas
#pegando base de dados do desafio Titianic do siate Kaggle
df = pd.read_csv('http://bit.ly/kaggletrain')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#pegando dados do sexo transformando dado categórico para numérico
pd.get_dummies(df.Sex).astype(int)
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
emb = pd.get_dummies(df.Embarked).astype(int)
emb
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
#concatenando
df = pd.concat([df, emb], axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2 = pd.get_dummies(df, columns=['Sex'], drop_first=True)
df2['Sex_male'] = df2['Sex_male'].astype(int)
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
#Dataset Peso e Altura
df_altura = pd.read_csv('/workspaces/descomplicaMBADataScience/weight-height.csv')
df_altura
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
from matplotlib import pyplot as plt

# %%
#gráfico histograma: weight é o campo, bins quantidade de barras, rwidth que é largura da barra
plt.hist(df_altura.Weight, bins=30, rwidth=0.8)
# Out:
# (array([  3.,   3.,   9.,  35.,  83., 160., 279., 409., 553., 682., 763.,
#         730., 641., 591., 617., 610., 693., 713., 665., 599., 483., 310.,
#         182., 106.,  43.,  22.,   6.,   9.,   0.,   1.]),
#  array([ 64.70012671,  71.54311244,  78.38609817,  85.22908389,
#          92.07206962,  98.91505534, 105.75804107, 112.6010268 ,
#         119.44401252, 126.28699825, 133.12998398, 139.9729697 ,
#         146.81595543, 153.65894116, 160.50192688, 167.34491261,
#         174.18789834, 181.03088406, 187.87386979, 194.71685551,
#         201.55984124, 208.40282697, 215.24581269, 222.08879842,
#         228.93178415, 235.77476987, 242.6177556 , 249.46074133,
#         256.30372705, 263.14671278, 269.98969851]),
#  <BarContainer object of 30 artists>)

# %%
#calcurando o zscore, que é a quantidade de desvios padrão. (mean é média e std que é o desvio padrão)
df_altura['zscore'] = (df_altura.Weight - df_altura.Weight.mean()) / df_altura.Weight.std()
df_altura
# Out:
#       Gender     Height      Weight    zscore
# 0       Male  73.847017  241.893563  2.505672
# 1       Male  68.781904  162.310473  0.027099
# 2       Male  74.110105  212.740856  1.597726
# 3       Male  71.730978  220.042470  1.825131
# 4       Male  69.881796  206.349801  1.398680
# ...      ...        ...         ...       ...
# 9995  Female  66.172652  136.777454 -0.768113
# 9996  Female  67.067155  170.867906  0.293616
# 9997  Female  63.867992  128.475319 -1.026678
# 9998  Female  69.034243  163.852461  0.075124
# 9999  Female  61.944246  113.649103 -1.488433
#
# [10000 rows x 4 columns]

# %%
#verifica se há 2 zscore ou seja, 2 desvio padrão (maior ou menor que 2) (| significa ou)
df_out2 = df_altura[(df_altura.zscore < -2) | (df_altura.zscore > 2)]
df_out2
# Out:
#       Gender     Height      Weight    zscore
# 0       Male  73.847017  241.893563  2.505672
# 23      Male  75.205974  228.761781  2.096689
# 82      Male  73.826127  237.916736  2.381816
# 190     Male  76.709835  235.035419  2.292078
# 191     Male  72.571121  230.560535  2.152711
# ...      ...        ...         ...       ...
# 9761  Female  56.975279   90.341784 -2.214327
# 9775  Female  60.025950   87.035416 -2.317302
# 9825  Female  55.979198   85.417534 -2.367690
# 9895  Female  57.740192   93.652957 -2.111202
# 9989  Female  60.955084   95.686674 -2.047863
#
# [225 rows x 4 columns]

# %%
#verifica se há 3 zscore ou seja, 3 desvio padrão (maior ou menor que 3) (| significa ou)
df_out3 = df_altura[(df_altura.zscore < -3) | (df_altura.zscore > 3)]
df_out3
# Out:
#       Gender     Height      Weight    zscore
# 2014    Male  78.998742  269.989699  3.380711
# 9285  Female  54.263133   64.700127 -3.012922
